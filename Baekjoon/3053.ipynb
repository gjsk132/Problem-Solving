# %% [markdown]
# 백준 3053 : 택시 기하학
#
# [[바로가기]](https://www.acmicpc.net/problem/3053)
#
# > 문제 요약
# - 유클리드 기하학 (원 넓이 : pi * r * r)
# - 택시 기하학 (원 넓이 : 2 * r * r)

# %%
input = open("input.txt").readline
from math import pi, sqrt

r = int(input())

print(r*r*pi)
print(2*r*r)
# Out:
# 5541.769440932395
# 3528
