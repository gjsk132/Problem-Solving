# %% [markdown]
# 백준 1074 : Z
#
# [[바로가기]](https://www.acmicpc.net/problem/1074)
#
# > 문제 요약
# > - 2^nx2^n인 2차원 배열을 Z모양을 탐색
# > - n이 주어질 때, (r, c)의 위치가 몇 번인지 출력한다.

# %%
input = open("input.txt").readline
n, row, col = map(int, input().split())

def z_setting(r, c, size):
    cnt = 0
    
    if size == 0:
        return 0

    ns = size//2

    if r <= row < r+ns and c <= col < c+ns:
        cnt += z_setting(r, c, ns)
    elif c <= col < c+ns:
        cnt += z_setting(r+ns, c, ns) + ns**2 * 2
    elif r <= row < r+ns:
        cnt += z_setting(r, c+ns, ns) + ns**2
    else:
        cnt += z_setting(r+ns, c+ns, ns) + ns**2 * 3
        
    return cnt

print(z_setting(0,0,2**n))
# Out:
# 47
