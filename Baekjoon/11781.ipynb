# %% [markdown]
# 백준 11781 : 퇴근 시간
#
# [[바로가기]](https://www.acmicpc.net/problem/11781)
#
# > 문제 요약
# - 퇴근까지 가장 오래걸리는 시간을 구하는 문제이다.
# - 지점 수 / 도로 수가 주어짐 / 퇴근 시간의 시작과 끝
# - start, end, 가중치, 퇴근 시간에 정체되는 경우 (A > B, B > A)
# - 모든 선택은 최대한 빨리 집에 도착하도록 한다.
#
#
# > 생각...
# - BFS > 1부터 시작해서 점점 퍼져나간다.
# - heapq + BFS > 같은 지점에 도착할 때, 최소 시간을 기준으로 pop한다. ( 시간이 가장 작을 때 기준 )
#
# - union find 써도 할 수 있을 것 같은디 ㅇㅅㅇ!
#
# - 가장 작은 시간 순으로 pop
# - pop 했을 때, 해당 지점의 visited가 False라면 pass? 진행 True라면? continue
# - 이전의 노드를 알아야 어느 방향으로 가는지 알 수 있고, 정체 구간의 유무를 알 수 있다.
# => [현재 시간][start node][end node]로 사용해볼까?
# => 시간 복잡도에 영향을 주는 것... 총 node와 link의 수에 따라 달라질 것 같음.
#
#
# > 시간 복잡도
# - N이 5,000...
# - M이 100,000...
# > M을 생각했을 때, 가능할 것 같음!
#
#
# > 시작과 끝을 기억할 때, 조금 더 편하게 기억할 순 없을까..?
#
# . N개의 노드가 주어질 때...
# A*N+B를 하면 바로 알 수 있지 않을까?
# (겹치지도 않는다.)
#
#
# > 문제 발생
# - 정체 구간에 의해서 단순히 다익스트라로 하기 힘들어졌음... 무슨 좋은 방법이 없을까
# - 정체 구간이랑 아닌 구간을 구분해서 해야할까...?
# - 정체가 아닌 구간은 0, 정체 구간 1
#
# - 시간 복잡도 떄문에 단순히 시간으로는 안된다.
# - 1에서 2(ex)로 갈 수 있는 모든 경우의 수를 찾는다...?
#
#
# - 단순하게... 최대한 정체 구간이 없으면서 작은 가중치를 가지는 것을 찾아야하지 않을까?
# - 정체 구간이 존재하지만, 정체인 구간을 포함하면서 가장 작은...?
#
# - 문제가 정체 시간을 피해갔을 때, 더욱 효율적인 결과를 낼 수 있는 경우가 있음
#
# 3 -> 5 >> 8이다.
# 2 -> 5(7) >> 2~3 까지 겹친다.
#
# 흐음 각 정체 구간에 언제 도착하냐에 따라서 결과가 바뀐다.
# (단순히 빠른게 좋은게 아니다.)
#
# 결국 모든 경우의 수를 구해야 할 것 같은데...
# (한 번 사용한 도로는 사용하지 못하는 방향으로 가야할까?)

# %%
from heapq import *
input = open("input.txt").readline

nodes, links, jam_start, jam_end = map(int,input().split())

jam_start *= 2
jam_end *= 2

board = [[] for _ in range(nodes+1)]
dist = [float('inf')]*(nodes+1)

for _ in range(links):
    s_node, e_node, w, s_to_e, e_to_s = map(int,input().split())

    heappush(board[s_node], (e_node, 2*w, s_to_e))
    heappush(board[e_node], (s_node, 2*w, e_to_s))

dist[1] = 0

dq = [(0, 1)]

while dq:
    now_t, now_node = heappop(dq)
    
    for next_node, w, isjam in board[now_node]:
        if isjam and jam_start < now_t + w and jam_end > now_t:
            
            traffic_jam_start = max(now_t, jam_start)

            if 2*(now_t + w - traffic_jam_start) < (jam_end - traffic_jam_start):
                w += (now_t + w - traffic_jam_start)
            else:
                w += (jam_end - traffic_jam_start)//2
        
        if dist[next_node] <= now_t + w:
            continue
        
        dist[next_node] = now_t + w

        heappush(dq, (now_t+w, next_node))

result = max(dist[1:])
print(result/2 if result%2 else result//2)
# Out:
# 16
